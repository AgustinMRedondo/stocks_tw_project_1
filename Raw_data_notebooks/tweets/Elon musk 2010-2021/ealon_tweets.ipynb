# %%
import pandas as pd #tablas https://pandas.pydata.org/docs/user_guide/pyarrow.html
import numpy as np #estadistica https://numpy.org/doc/1.25/user/index.html#user
import matplotlib.pyplot as plt #gráficos https://matplotlib.org/stable/plot_types/index.html
import seaborn as sns #gráficos https://seaborn.pydata.org/tutorial/regression.html
from sklearn import linear_model #modelo de regresion https://scikit-learn.org/stable/
from sklearn.preprocessing import MinMaxScaler # do not use the function Normalise() - it does something entirely different
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from datetime import datetime #https://docs.python.org/3/library/datetime.html
from datetime import timedelta #this is a good time to learn about dates and timestamps. You can find some info here:
from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import ttest_1samp
import scipy.stats as st
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.plotting import plot_decision_regions
import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication
from getpass import getpass  # To get the password without showing the input

# %%
df = pd.read_csv("TweetsElonMusk.csv")

# %%
df
# Out:
#                         id      conversation_id                created_at  \
# 0      1381273474400800773  1381002894032347138  2021-04-11 18:50:33 EEST
# 1      1381273076709478403  1372444955050971142  2021-04-11 18:48:58 EEST
# 2      1381258144916008964  1381230136918433792  2021-04-11 17:49:38 EEST
# 3      1381221447322935303  1381221447322935303  2021-04-11 15:23:49 EEST
# 4      1381129584435818496  1381079981485252611  2021-04-11 09:18:47 EEST
# ...                    ...                  ...                       ...
# 12557  1382255613665701894  1382189497694121990  2021-04-14 11:53:14 EEST
# 12558  1382239892445401089  1382189497694121990  2021-04-14 10:50:45 EEST
# 12559  1382239304097824768  1382189497694121990  2021-04-14 10:48:25 EEST
# 12560  1382131928619495429  1382046129450258434  2021-04-14 03:41:45 EEST
# 12561  1382052264802721792  1382046129450258434  2021-04-13 22:25:11 EEST
#
#              date      time  timezone   user_id  username       name  place  \
# 0      2021-04-11  18:50:33       300  44196397  elonmusk  Elon Musk    NaN
# 1      2021-04-11  18:48:58       300  44196397  elonmusk  Elon Musk    NaN
# 2      2021-04-11  17:49:38       300  44196397  elonmusk  Elon Musk    NaN
# 3      2021-04-11  15:23:49       300  44196397  elonmusk  Elon Musk    NaN
# 4      2021-04-11  09:18:47       300  44196397  elonmusk  Elon Musk    NaN
# ...           ...       ...       ...       ...       ...        ...    ...
# 12557  2021-04-14  11:53:14       300  44196397  elonmusk  Elon Musk    NaN
# 12558  2021-04-14  10:50:45       300  44196397  elonmusk  Elon Musk    NaN
# 12559  2021-04-14  10:48:25       300  44196397  elonmusk  Elon Musk    NaN
# 12560  2021-04-14  03:41:45       300  44196397  elonmusk  Elon Musk    NaN
# 12561  2021-04-13  22:25:11       300  44196397  elonmusk  Elon Musk    NaN
#
#        ... geo source user_rt_id user_rt retweet_id  \
# 0      ... NaN    NaN        NaN     NaN        NaN
# 1      ... NaN    NaN        NaN     NaN        NaN
# 2      ... NaN    NaN        NaN     NaN        NaN
# 3      ... NaN    NaN        NaN     NaN        NaN
# 4      ... NaN    NaN        NaN     NaN        NaN
# ...    ...  ..    ...        ...     ...        ...
# 12557  ... NaN    NaN        NaN     NaN        NaN
# 12558  ... NaN    NaN        NaN     NaN        NaN
# 12559  ... NaN    NaN        NaN     NaN        NaN
# 12560  ... NaN    NaN        NaN     NaN        NaN
# 12561  ... NaN    NaN        NaN     NaN        NaN
#
#                                                 reply_to  retweet_date  \
# 0      [{'screen_name': 'vincent13031925', 'name': 'V...           NaN
# 1                                                     []           NaN
# 2      [{'screen_name': 'agnostoxxx', 'name': 'Shrubb...           NaN
# 3                                                     []           NaN
# 4      [{'screen_name': 'itsALLrisky', 'name': '💸💸💸',...           NaN
# ...                                                  ...           ...
# 12557  [{'screen_name': 'eugenelee3', 'name': 'eugene...           NaN
# 12558  [{'screen_name': 'PPathole', 'name': 'Pranay P...           NaN
# 12559  [{'screen_name': 'PPathole', 'name': 'Pranay P...           NaN
# 12560  [{'screen_name': 'Erdayastronaut', 'name': 'Ev...           NaN
# 12561  [{'screen_name': 'Erdayastronaut', 'name': 'Ev...           NaN
#
#        translate trans_src trans_dest
# 0            NaN       NaN        NaN
# 1            NaN       NaN        NaN
# 2            NaN       NaN        NaN
# 3            NaN       NaN        NaN
# 4            NaN       NaN        NaN
# ...          ...       ...        ...
# 12557        NaN       NaN        NaN
# 12558        NaN       NaN        NaN
# 12559        NaN       NaN        NaN
# 12560        NaN       NaN        NaN
# 12561        NaN       NaN        NaN
#
# [12562 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
musk = df[["date", "username", "tweet", "retweets_count", "likes_count"]]
musk
# Out:
#              date  username  \
# 0      2021-04-11  elonmusk
# 1      2021-04-11  elonmusk
# 2      2021-04-11  elonmusk
# 3      2021-04-11  elonmusk
# 4      2021-04-11  elonmusk
# ...           ...       ...
# 12557  2021-04-14  elonmusk
# 12558  2021-04-14  elonmusk
# 12559  2021-04-14  elonmusk
# 12560  2021-04-14  elonmusk
# 12561  2021-04-13  elonmusk
#
#                                                    tweet  retweets_count  \
# 0      @vincent13031925 For now. Costs are decreasing...             444
# 1                               Love this beautiful shot            1517
# 2      @agnostoxxx @CathieDWood @ARKInvest Trust the ...              48
# 3                     The art In Cyberpunk is incredible           10329
# 4                                        @itsALLrisky 🤣🤣             542
# ...                                                  ...             ...
# 12557  @eugenelee3 @PPathole @SpaceX @Tesla Yeah, not...             102
# 12558  @PPathole @SpaceX @Tesla That was my night job...             270
# 12559  @PPathole @SpaceX @Tesla True. Ancient times …...            1158
# 12560                  @Erdayastronaut @Tesla Absolutely             204
# 12561  @Erdayastronaut @Tesla Tesla is building up co...            1192
#
#        likes_count
# 0            15281
# 1            71161
# 2             1380
# 3           228144
# 4             7489
# ...            ...
# 12557         2362
# 12558         5209
# 12559        46198
# 12560         6051
# 12561        26888
#
# [12562 rows x 5 columns]

# %%
musk.isna().sum()
# Out:
# date              0
# username          0
# tweet             0
# retweets_count    0
# likes_count       0
# dtype: int64

# %%
musk_sorted = musk.sort_values(by='date', ascending=True).reset_index(drop=True)
musk_sorted
# Out:
#              date  username  \
# 0      2010-06-04  elonmusk
# 1      2011-12-01  elonmusk
# 2      2011-12-01  elonmusk
# 3      2011-12-03  elonmusk
# 4      2011-12-03  elonmusk
# ...           ...       ...
# 12557  2021-04-17  elonmusk
# 12558  2021-04-17  elonmusk
# 12559  2021-04-17  elonmusk
# 12560  2021-04-17  elonmusk
# 12561  2021-04-17  elonmusk
#
#                                                    tweet  retweets_count  \
# 0      Please ignore prior tweets, as that was someon...             349
# 1      Went to Iceland on Sat to ride bumper cars on ...              16
# 2      I made the volume on the Model S  http://t.co/...               9
# 3      Great Voltaire quote, arguably better than Twa...              24
# 4                      That was a total non sequitur btw               6
# ...                                                  ...             ...
# 12557                            Everything to the moon!           42839
# 12558  @neuralink @shivon Great review! Neuralink is ...             628
# 12559  If we make life multiplanetary, there may come...            8411
# 12560  Dragon spacecraft &amp; Falcon 9 rocket  https...            5355
# 12561        @WhatsupFranks Great progress by Tesla team             167
#
#        likes_count
# 0             4710
# 1              191
# 2               79
# 3               30
# 4               52
# ...            ...
# 12557       300427
# 12558         6155
# 12559        87303
# 12560        64372
# 12561         3480
#
# [12562 rows x 5 columns]

# %% [markdown]
# Let's add the company_id TSLA, to all the rows, and save it in the SQL of raw_data as Tesla_tweets_raw

# %%
musk_sorted["company_id"] = "TSLA"
tesla_tweets_raw = musk_sorted[["company_id"] + [col for col in musk_sorted.columns if col != "company_id"]]
tesla_tweets_raw
# Out:
#       company_id        date  username  \
# 0           TSLA  2010-06-04  elonmusk
# 1           TSLA  2011-12-01  elonmusk
# 2           TSLA  2011-12-01  elonmusk
# 3           TSLA  2011-12-03  elonmusk
# 4           TSLA  2011-12-03  elonmusk
# ...          ...         ...       ...
# 12557       TSLA  2021-04-17  elonmusk
# 12558       TSLA  2021-04-17  elonmusk
# 12559       TSLA  2021-04-17  elonmusk
# 12560       TSLA  2021-04-17  elonmusk
# 12561       TSLA  2021-04-17  elonmusk
#
#                                                    tweet  retweets_count  \
# 0      Please ignore prior tweets, as that was someon...             349
# 1      Went to Iceland on Sat to ride bumper cars on ...              16
# 2      I made the volume on the Model S  http://t.co/...               9
# 3      Great Voltaire quote, arguably better than Twa...              24
# 4                      That was a total non sequitur btw               6
# ...                                                  ...             ...
# 12557                            Everything to the moon!           42839
# 12558  @neuralink @shivon Great review! Neuralink is ...             628
# 12559  If we make life multiplanetary, there may come...            8411
# 12560  Dragon spacecraft &amp; Falcon 9 rocket  https...            5355
# 12561        @WhatsupFranks Great progress by Tesla team             167
#
#        likes_count
# 0             4710
# 1              191
# 2               79
# 3               30
# 4               52
# ...            ...
# 12557       300427
# 12558         6155
# 12559        87303
# 12560        64372
# 12561         3480
#
# [12562 rows x 6 columns]

# %%
password = getpass()

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/raw_data'
engine = create_engine(connection_string)

# %%
#tesla_tweets_raw.to_sql('tesla_tweets_raw', engine, if_exists='append', index=False)
# Out:
# 12562
