# %%
import pandas as pd
import numpy as np

import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication

from getpass import getpass  # To get the password without showing the input

# %% [markdown]
# Establish connection

# %%
password = getpass()

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/raw_data'
engine = create_engine(connection_string)

# %% [markdown]
# Bring excel/csv and turn it into pd.dataframes we can push to the data base

# %%
companies = pd.read_excel("../Raw_data_notebooks/companies.xlsx")

# %%
companies
# Out:
#   company_id                   name  \
# 0       TSLA            Tesla, Inc.
# 1       META   Meta Platforms, Inc.
# 2       GOOG          Alphabet Inc.
# 3        NIO               NIO Inc.
# 4       AAPL             Apple Inc.
# 5       AMZN       Amazon.com, Inc.
# 6       MSFT  Microsoft Corporation
#
#                                              address        country  \
# 0                     1 Tesla Road\nAustin, TX 78725  United States
# 1             1601 Willow Road\nMenlo Park, CA 94025  United States
# 2  1600 Amphitheatre Parkway\nMountain View, CA 9...  United States
# 3  Building 20\nNo. 56 AnTuo Road Anting Town Jia...          China
# 4            One Apple Park Way\nCupertino, CA 95014  United States
# 5     410 Terry Avenue North\nSeattle, WA 98109-5210  United States
# 6          One Microsoft Way\nRedmond, WA 98052-6399  United States
#
#                        website                          sector  num_employees  \
# ...

# %%
companies["company_id"].unique()
# Out:
# array(['TSLA', 'META', 'GOOG', 'NIO', 'AAPL', 'AMZN', 'MSFT'],
#       dtype=object)

# %% [markdown]
# # FIRST CREATE THE COLUMNS AND THE DATA SET IN MY SQL

# %%
companies.to_sql('companies', engine, if_exists='append', index=False)
# Out:
# 7

# %% [markdown]
# Now with board members

# %%
bm = pd.read_excel("../Raw_data_notebooks/board_members.xlsx")

# %%
bm
# Out:
#    company_id                          name  \
# 0        TSLA                   Tesla, Inc.
# 1        TSLA              Mr. Elon R. Musk
# 2        TSLA         Mr. Andrew D. Baglino
# 3        TSLA             Mr. Martin Viecha
# 4        TSLA       Mr. Jeffrey B. Straubel
# 5        TSLA      Mr. Franz von Holzhausen
# 6        TSLA           Ms. Sarah Maryssael
# 7        META          Meta Platforms, Inc.
# 8        META    Mr. Mark Elliot Zuckerberg
# 9        META             Mr. Javier Olivan
# 10       META           Mr. Andrew Bosworth
# 11       META        Mr. Christopher K. Cox
# 12       META           Mr. David M. Wehner
# 13       META         Mr. Aaron A. Anderson
# 14       GOOG                 Alphabet Inc.
# 15       GOOG             Mr. Sundar Pichai
# 16       GOOG      Mr. Lawrence Edward Page
# 17       GOOG               Mr. Sergey Brin
# 18       GOOG             Ms. Ruth M. Porat
# 19       GOOG            Mr. J. Kent Walker
# ...

# %% [markdown]
# CAREFUL! TO ADD NEW DATA BRING

# %%
bm.to_sql('board_members', engine, if_exists='append', index=False)
# Out:
# 44
